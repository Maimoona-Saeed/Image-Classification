jpg
#   inflating: /content/DataSet/DataSet/Data_desert/desert(411).jpg
#   inflating: /content/DataSet/DataSet/Data_desert/desert(412) (1).jpg
#   inflating: /content/DataSet/DataSet/Data_desert/desert(413) (1).jpg
#   inflating: /content/DataSet/DataSet/Data_desert/desert(416).jpg
#   inflating: /content/DataSet/DataSet/Data_desert/desert(417).jpg
#   inflating: /content/DataSet/DataSet/Data_desert/desert(418).jpg
#   inflating: /content/DataSet/DataSet/Data_desert/desert(419).jpg
#   inflating: /content/DataSet/DataSet/Data_desert/desert(42).jpg
# ...
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1766.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1770.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_18.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_181.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1824.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1828.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1846.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1848.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1856.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1867.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_188.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1886.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1888.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1896.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_190.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1920.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1964.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1974.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_1977.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2001.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2003.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2028.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2029.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2046.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2065.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_207.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2140.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2142.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2161.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_218.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2188.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2190.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_221.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2219.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2221.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2230.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2231.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2240.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_226.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2270.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2275.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2279.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2288.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2316.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2333.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_234.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2346.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2380.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_239.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_240.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2403.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2416.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2417.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_245.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2452.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2467.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2471.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2478.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2494.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2496.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2517.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2521.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2527.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2529.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2532.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2534.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2538.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2553.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2568.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_257.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2586.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2591.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_261.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2618.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2624.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2628.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2635.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2638.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_264.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2651.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2685.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2690.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2719.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2721.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2742.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2746.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2753.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2757.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2767.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_277.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2773.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2783.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2794.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_280.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2808.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2809.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_282.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2820.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2824.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2826.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2832.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2843.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2851.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2852.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2863.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2864.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2867.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_287.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2873.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2882.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2887.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2892.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2897.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_290.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2900.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2905.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2908.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2923.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_293.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2941.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2955.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2958.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_296.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2972.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2974.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2975.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2990.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_2999.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_303.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_316.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_323.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_33.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_332.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_333.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_347.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_348.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_35.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_350.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_359.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_379.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_40.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_400.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_403.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_406.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_418.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_502.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_504.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_51.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_513.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_52.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_538.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_559.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_572.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_579.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_585.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_602.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_605.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_628.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_632.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_646.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_657.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_66.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_664.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_668.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_67.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_675.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_680.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_686.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_687.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_688.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_693.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_7.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_700.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_702.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_703.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_706.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_709.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_723.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_724.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_725.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_726.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_738.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_743.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_744.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_754.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_76.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_763.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_767.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_768.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_773.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_774.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_782.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_788.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_79.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_801.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_806.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_81.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_812.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_819.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_822.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_837.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_844.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_85.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_851.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_856.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_861.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_864.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_867.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_869.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_87.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_870.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_873.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_876.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_888.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_89.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_896.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_9.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_90.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_900.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_910.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_92.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_923.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_924.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_941.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_943.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_947.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_95.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_950.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_956.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_966.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_974.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_98.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_983.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_984.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_985.jpg
#   inflating: /content/DataSet/DataSet/Data_water/SeaLake_997.jpg

# %%
# Check the contents of the extracted directory
# !ls /content/DataSet.zip
# Out:
# /content/DataSet.zip

# %%
#  Data Loading and Preparation
# ----------------------------------------------

# Use image_dataset_from_directory for simplicity
dataset_dir = '/content/DataSet/DataSet'  # Corrected path to the directory containing class subdirectories

# Split dataset into train/val/test
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.3,
    subset="training",
    seed=123,
    image_size=(224, 224),  # Standard input size for ConvNeXt, Swin, VGG19
    batch_size=32
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.15,
    subset="validation",
    seed=123,
    image_size=(224, 224),
    batch_size=32
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.15,
    subset="validation",
    seed=456,  # Different seed to simulate test split
    image_size=(224, 224),
    batch_size=32
)
class_names = train_ds.class_names
# Out:
# Found 1800 files belonging to 4 classes.
# Using 1260 files for training.
# Found 1800 files belonging to 4 classes.
# Using 270 files for validation.
# Found 1800 files belonging to 4 classes.
# Using 270 files for validation.

# %%
# Prefetch for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)

# %%
# Helper: Plot Metrics + Confusion Matrix
# ----------------------------------------------
def plot_metrics(history, title):
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Train Acc')
    plt.plot(history.history['val_accuracy'], label='Val Acc')
    plt.title(f'{title} Accuracy')
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title(f'{title} Loss')
    plt.legend()
    plt.show()

def compute_specificity(cm):
    """
    Compute specificity for each class from confusion matrix.
    Specificity = TN / (TN + FP)
    """
    specificity = []
    for i in range(len(cm)):
        tn = np.sum(np.delete(np.delete(cm, i, axis=0), i, axis=1))
        fp = np.sum(np.delete(cm, i, axis=0)[:, i])
        spec = tn / (tn + fp) if (tn + fp) > 0 else 0
        specificity.append(spec)
    return specificity

def plot_confusion(y_true, y_pred, labels):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# %%
# ConvNeXt Model
# ----------------------------------------------
def build_convnext():
    base = keras.applications.ConvNeXtTiny(weights='imagenet', include_top=False, input_shape=(224,224,3))
    base.trainable = False
    model = keras.Sequential([
        data_augmentation,
        base,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(len(class_names), activation='softmax')
    ])
    return model

# %%
# Swin Transformer Model
# ----------------------------------------------
def build_swin():

    base = keras.applications.SwinTransformerTiny(weights='imagenet', include_top=False, input_shape=(224,224,3))
    base.trainable = False
    model = keras.Sequential([
        data_augmentation,
        base,
        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(len(class_names), activation='softmax')
    ])
    return model

# %%
# VGG19 Transfer Learning
# ----------------------------------------------
def build_vgg19():
    base = keras.applications.VGG19(weights='imagenet', include_top=False, input_shape=(224,224,3))
    base.trainable = True  # fine-tune
    model = keras.Sequential([
        data_augmentation,
        base,
        layers.GlobalAveragePooling2D(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(len(class_names), activation='softmax')
    ])
    return model

# %%
# Custom CNN
# ----------------------------------------------
def build_custom():
    inputs = keras.Input(shape=(224,224,3))
    x = data_augmentation(inputs)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, (3,3), padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        x = layers.MaxPooling2D()(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(0.5)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(len(class_names), activation='softmax')(x)
    model = keras.Model(inputs, outputs)
    return model

# %%
# Training + Evaluation
# ----------------------------------------------
def train_and_evaluate(model, title):
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    history = model.fit(train_ds, validation_data=val_ds, epochs=10)
    plot_metrics(history, title)

    # Evaluate on test
    y_true = []
    y_pred = []
    for imgs, labels in test_ds:
        preds = model.predict(imgs)
        y_true.extend(labels.numpy())
        y_pred.extend(np.argmax(preds, axis=1))

    plot_confusion(y_true, y_pred, class_names)
    print(classification_report(y_true, y_pred, target_names=class_names))

    # Compute and print specificity
    cm = confusion_matrix(y_true, y_pred) # Calculate confusion matrix
    spec = compute_specificity(cm)
    print("\nSpecificity (per class):")
    for lbl, s in zip(class_names, spec):
        print(f"{lbl}: {s:.2f}")

# %%
# Data Augmentation
# ----------------------------------------------
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

# %%
# Build, train, and evaluate the Custom CNN model
custom_model = build_custom()
train_and_evaluate(custom_model, "Custom CNN")
# Out:
# Epoch 1/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 159ms/step - accuracy: 0.7689 - loss: 4.7962 - val_accuracy: 0.6778 - val_loss: 38.4918
# Epoch 2/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 144ms/step - accuracy: 0.8483 - loss: 1.0074 - val_accuracy: 0.7148 - val_loss: 5.3254
# Epoch 3/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8961 - loss: 0.2715 - val_accuracy: 0.7000 - val_loss: 3.8069
# Epoch 4/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.8638 - loss: 0.2659 - val_accuracy: 0.7185 - val_loss: 1.5080
# Epoch 5/10
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8662 - loss: 0.6466 - val_accuracy: 0.8000 - val_loss: 0.3621
# Epoch 6/10
# 26/40 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.9170 - loss: 0.4737

# %%
def generate_adversarial(model, image, label, epsilon=0.01):
    image = tf.convert_to_tensor(image)
    label = tf.convert_to_tensor([label])
    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        loss = tf.keras.losses.sparse_categorical_crossentropy(label, prediction)
    gradient = tape.gradient(loss, image)
    perturbation = epsilon * tf.sign(gradient)
    adversarial_image = image + perturbation
    return tf.clip_by_value(adversarial_image, 0, 1)

# model = build_convnext()
# train_and_evaluate(model, "ConvNeXt")
# model = build_swin()
# train_and_evaluate(model, "Swin Transformer")
# model = build_vgg19()
# train_and_evaluate(model, "VGG19")
# model = build_custom()
# train_and_evaluate(model, "Custom CNN")

# %%
model = build_convnext()

# %%
train_and_evaluate(model, "ConvNeXt")

# %%
def build_swin():
    # Replace SwinTransformerTiny with a commonly available model like ResNet50
    base = keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
    base.trainable = False
    model = keras.Sequential([
        data_augmentation,
        base,
        layers.GlobalAveragePooling2D(),
        layers.Dense(4, activation='softmax') # Assuming 4 classes
    ])
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

model = build_swin()

# %%
train_and_evaluate(model, "Swin Transformer")

# %%
model = build_vgg19()

# %%
train_and_evaluate(model, "VGG19")

# %%
model = build_custom()

# %%
train_and_evaluate(model, "Custom CNN")

# %%
# Optional to compare the performance of all these models and conclude results
# ---------------------------------------------------------------------------------

from sklearn.metrics import classification_report
import pandas as pd

# Dictionary to store results
results = {}

def train_and_evaluate_collect(model_fn, title):
    print(f"\n Training {title}...")
    model = model_fn()
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    # Fit model
    history = model.fit(train_ds, validation_data=val_ds, epochs=10, verbose=0)

    # Evaluate
    y_true, y_pred = [], []
    for imgs, labels in test_ds:
        preds = model.predict(imgs, verbose=0)
        y_true.extend(labels.numpy())
        y_pred.extend(np.argmax(preds, axis=1))

    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

    # Collect macro avg
    macro_avg = report['macro avg']

    results[title] = {
        'accuracy': report['accuracy'],
        'precision': macro_avg['precision'],
        'recall': macro_avg['recall'],
        'f1-score': macro_avg['f1-score']
    }

    # Optional: print detailed report
    print(classification_report(y_true, y_pred, target_names=class_names))

#  Run all models
train_and_evaluate_collect(build_convnext, "ConvNeXt")
train_and_evaluate_collect(build_swin, "Swin Transformer")
train_and_evaluate_collect(build_vgg19, "VGG19")
train_and_evaluate_collect(build_custom, "Custom CNN")

#  Display comparison
df_results = pd.DataFrame(results).T
print("\n Model Comparison:\n")
print(df_results)

# If you want, plot as bar chart
df_results.plot(kind='bar', figsize=(10,6), title='Model Performance Comparison (Macro Avg)')
